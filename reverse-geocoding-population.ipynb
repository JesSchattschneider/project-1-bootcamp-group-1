# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import pandas as pd
import time

# %%
df_population = pd.read_csv("world-city-listing-table.csv")

# %%
# Initialize geocoder
geolocator = Nominatim(user_agent="job_location_parser")

def _parse_location(location):
    # Handle NA or None values
    if pd.isna(location) or location.upper() == "NA":
        return ("Unknown", "Unknown")

    # Handle remote jobs separately
    if "REMOTE" in location.upper():
        return ("Remote", "Remote")
    
    # Handle remote jobs with no location specified separately
    if location.upper() == "NONE":
        return ("Unknown", "Unknown")

    attempt = 0
    while attempt < 5:
        try:
            # Geocode the location
            location_geo = geolocator.geocode(location, language='en')
            if location_geo:
                # Split the address into components
                address_parts = location_geo.address.split(',')
                # Extract the relevant parts
                country = address_parts[-1].strip()
                city = address_parts[0].strip() if len(address_parts) > 0 else "Unknown"
                
                # Check for administrative areas in the address parts
                if len(address_parts) > 2:
                    if any(keyword in address_parts[-3].lower() for keyword in ["city", "town", "village", "municipality"]):
                        city = address_parts[-3].strip()
                    elif any(keyword in address_parts[-2].lower() for keyword in ["city", "town", "village", "municipality"]):
                        city = address_parts[-2].strip()
                return (city, country)
            else:
                return ("Unknown", "Unknown")
        except GeocoderTimedOut:
            attempt += 1
            print(f"Timeout occurred for {location}. Retrying... (Attempt {attempt})")
            time.sleep(2 ** attempt)  # Exponential backoff
        except Exception as e:
            print(f"Exception: {e}")
            return ("Unknown", "Unknown")
    return ("Unknown", "Unknown")

# %%
# Set all columns to lowercase 
df_population.columns = map(str.lower, df_population.columns)
# combine city and country columns into location column
df_population['location'] = df_population['city'] + ", " + df_population['country']

# Handle location column
df_population[['city_geopy', 'country_geopy']] = df_population['location'].apply(lambda x: pd.Series(_parse_location(x)))

# Set values in all columns to lowercase
df_population = df_population.apply(lambda x: x.astype(str).str.lower())

# save
df_population.to_csv("world-city-listing-table-geopy-raw.csv", index=False)

# %%
# print all the unique locations that could not be geocoded
print(df_population[df_population['city_geopy'] == "unknown"]['location'].unique())
# Out:
#   population   pop2024   pop2023       city     country growthrate type rank  \
# 0   37115035  37115035  37194105      tokyo       japan    -0.0021    w    1
# 1   33807403  33807403  32941309      delhi       india     0.0263    w    2
# 2   29867918  29867918  29210808   shanghai       china     0.0225    w    3
# 3   23935652  23935652  23209616      dhaka  bangladesh     0.0313    w    4
# 4   22806704  22806704  22619736  sao paulo      brazil     0.0083    w    5
#
#             location city_geopy country_geopy
# 0       tokyo, japan      tokyo         japan
# 1       delhi, india      delhi         india
# 2    shanghai, china   shanghai         china
# 3  dhaka, bangladesh      dhaka    bangladesh
# 4  sao paulo, brazil  são paulo        brazil

# %%
# clean df_population remove rows with unknown city_geopy
df_population = df_population[df_population['city_geopy'] != "unknown"]
# save cleaned df_population
df_population.to_csv("world-city-listing-table-geopy-clean.csv", index=False)

# %%
fw_data_raw = pd.read_csv("findwork_data_raw.csv")

# %%
# print all unique values in the location column
# print(fw_data_raw['location'].unique())

# %%
# filter keep only remote = false
fw_data = fw_data_raw[fw_data_raw['remote'] == False]
# remove location = nan
fw_data = fw_data[fw_data['location'].notna()]

# if locations contains remote, set remote to true
fw_data['remote'] = fw_data['location'].apply(lambda x: True if "remote" in x.lower() else False)
# filter keep only remote = false
fw_data = fw_data[fw_data['remote'] == False]

# %%
fw_data.drop_duplicates(subset=['location'])
# Out:
#           id                                               role  \
# 1    M1pNwaQ                             mid+ engineering roles
# 19   M3GNp2M  Senior/Staff Engineer, Lead Frontend Engineer,...
# 30   M3GYPBM  Biomedical Engineer // Quantune Technologies GmbH
# 48   MAdNAdQ                     Full-stack / Frontend Engineer
# 49   MAdNwVQ           Machine Learning Engineer, Data Engineer
# 68   MBjrE1M                   Risk Manager - Liquid Token Fund
# 74   MBjRzBM                                 Platform Engineers
# 86   MdV9PDn                        Senior Industrial Designer
# 88   MdV9xWn                                     Multiple Roles
# 91   MdVg2xn               Senior Developer Experience Engineer
# 99   MdVyVDn                                       AI Developer
# 119  MLrVron                         Research Software Engineer
# 124  MmjBeWX                                  Software Engineer
# 148  MNNWzLM              Senior Python Engineer (Feature Team)
# 149  MrJG9KM                              Quant Python Engineer
# 151  MrJKArM                                  Software Engineer
# 185  n2YKGbX       Many roles - Sr. Java / Data / AI/ML / React
# 204  n5ZN0eQ                         Software engineer (4+ YOE)
# 207  n7le07Q          Assistant Professor of Industrial Design
# 220  n7lNYBQ                              DevOps/DevEx engineer
# 230  n98przX                         Senior Full Stack Engineer
# 231  n98qDJX                 Software engineer - Infrastructure
# 242  nal5qAX    Software Engineers (C++ / RUST / Data Platform)
# 269  nD5NAjQ  Senior Software Engineers, Full Stack, App Stu...
# 274  njj0WZn                                     Multiple roles
# 286  njjzx2n                          Senior Front-End Engineer
# 328  npR3EyM                    Data & Software Engineer Intern
# 345  nvDY52M             Vice President, Crypto Investment Risk
# 357  nvDZwLM                                     Multiple roles
# 435  Q4qPwNM                                Front-end Engineers
# 439  Q4qRarM  Director, Trading Engineering (Technical/IC Role)
# 447  Q6217gQ                      Senior Software Engineer, C++
# 449  Q621oBQ  Finance, Cloud Operations, Customer Support, E...
# 450  Q621omQ                             Senior DevOps Engineer
# 475  Qg6L4Rn                                  Project Architect
# 524  QV5Bd7n            Software Engineers (full-stack, mobile)
# 545  X88wapX                          Technical Product Manager
# 556  XE59ErX                             Token Growth Associate
# 559  XE59mjX  Industrial Product Designer(with relocation al...
# 578  XkR9r5M                           Senior Frontend Engineer
# 614  XO9mlqQ                                 Multiple Positions
# 692  Xxq5yOn    Senior + Mid Level System Development Engineers
#
#                     company_name company_num_employees employment_type  \
# 1                        GA-CCRi                   NaN             NaN
# 19                     Hashboard                   NaN             NaN
# 30         Quantune Technologies                   NaN       full time
# 48                        Napper                   NaN             NaN
# 49                           ML6                   NaN             NaN
# 68                   ARP Digital                   NaN       full time
# 74                    prokube.ai                   NaN             NaN
# 86                     Solventum                   NaN             NaN
# 88                  Seen Finance                   NaN             NaN
# 91                        Novata                   NaN             NaN
# 99                      ABN AMRO               251-500             NaN
# 119             Honda R&D Europe                   NaN             NaN
# 124                  Silobreaker                   NaN             NaN
# 148                      Datenna                   NaN             NaN
# 149               Man Group Tech                   NaN             NaN
# 151                      Fulcrum                 11-50             NaN
# 185                adMarketplace                51-100             NaN
# 204                      Numeric                   NaN             NaN
# 207     Arizona State University                   NaN             NaN
# 220                        Opvia                   NaN             NaN
# 230                      Bonside                   NaN             NaN
# 231                    Assembled                   NaN             NaN
# 242                     Freeform                   NaN             NaN
# 269                       Plotly                   NaN             NaN
# 274                        Asana               251-500             NaN
# 286                     TandemAI                   NaN             NaN
# 328                       Ledger                   NaN             NaN
# 345      Fidelity Digital Assets                   NaN       full time
# 357                        Asana               251-500             NaN
# 435            KPV LAB Edinburgh                   NaN             NaN
# 439      Fidelity Digital Assets                   NaN       full time
# 447                       Ripple                   NaN             NaN
# 449                    Backblaze                51-100             NaN
# 450         Fidelity Investments                   NaN       full time
# 475  Food Plant Engineering, LLC                   NaN             NaN
# 524                   Radar Labs                   NaN             NaN
# 545               Injective Labs                   NaN       full time
# 556             Outlier Ventures                   NaN       full time
# 559                        Puffy                   NaN             NaN
# 578                       Neocom                   NaN             NaN
# 614                          SIG                   NaN             NaN
# 692                          AWS                   NaN             NaN
#
#                                          location  remote  \
# 1             onsite (hybrid or full): VA, DC, UT   False
# 19                                 New York (NYC)   False
# 30                                Berlin, Germany   False
# 48                                      Stockholm   False
# 49   Amsterdam, Berlin, Ghent (EU) On-site/hybrid   False
# 68                    Dubai, United Arab Emirates   False
# 74           Northern Germany (Hamburg or Bremen)   False
# 86                                  Maplewood, MN   False
# 88                                         Berlin   False
# 91                            London, UK (Hybrid)   False
# 99                         Amsterdam, Netherlands   False
# 119                                            UK   False
# 124              Hybrid - Onsite in Stockholm, SE   False
# 148                On-site Eindhoven, Netherlands   False
# 149                                    London, UK   False
# 151                            London or New York   False
# 185                              New York, NY USA   False
# 204        ONSITE in San Francisco, CA or NYC, NY   False
# 207                                     Tempe, AZ   False
# 220                             London (UK based)   False
# 230                           New York City (NYC)   False
# 231                             San Francisco, CA   False
# 242                              Los Angeles, Ca.   False
# 269                                        Canada   False
# 274   San Francisco, New York, Vancouver & Warsaw   False
# 286                       HYBRID in New York City   False
# 328                                 Paris, France   False
# 345                         Boston, United States   False
# 357    San Francisco, New York, Vancouver& Warsaw   False
# 435                                 Edinburgh, UK   False
# 439                    Jersey City, United States   False
# 447                           Toronto/ London, UK   False
# 449                                 San Mateo, CA   False
# 450                         Durham, United States   False
# 475                                Cincinnati, OH   False
# 524                       ONSITE in New York City   False
# 545                       New York, United States   False
# 556                        London, United Kingdom   False
# 559                               Los Angeles, CA   False
# 578                               Munich, Germany   False
# 614                             SYDNEY, Australia   False
# 692                                   Redmond, WA   False
#
#                                                   logo  \
# 1                                                  NaN
# 19                                                 NaN
# 30   https://findwork-dev-images.s3.amazonaws.com/f...
# 48                                                 NaN
# 49    https://findwork-dev-images.s3.amazonaws.com/ML6
# 68   https://findwork-dev-images.s3.amazonaws.com/f...
# 74                                                 NaN
# 86                                                 NaN
# 88                                                 NaN
# 91                                                 NaN
# 99   https://findwork-dev-images.s3.amazonaws.com/A...
# 119                                                NaN
# 124                                                NaN
# 148                                                NaN
# 149                                                NaN
# 151                                                NaN
# 185  https://findwork-dev-images.s3.amazonaws.com/a...
# 204                                                NaN
# 207  https://findwork-dev-images.s3.amazonaws.com/A...
# 220                                                NaN
# 230                                                NaN
# 231  https://findwork-dev-images.s3.amazonaws.com/A...
# 242                                                NaN
# 269                                                NaN
# 274  https://findwork-dev-images.s3.amazonaws.com/A...
# 286                                                NaN
# 328  https://findwork-dev-images.s3.amazonaws.com/f...
# 345  https://findwork-dev-images.s3.amazonaws.com/f...
# 357  https://findwork-dev-images.s3.amazonaws.com/A...
# 435  https://findwork-dev-images.s3.amazonaws.com/K...
# 439  https://findwork-dev-images.s3.amazonaws.com/f...
# 447  https://findwork-dev-images.s3.amazonaws.com/R...
# 449  https://findwork-dev-images.s3.amazonaws.com/B...
# 450  https://findwork-dev-images.s3.amazonaws.com/f...
# 475                                                NaN
# 524                                                NaN
# 545  https://findwork-dev-images.s3.amazonaws.com/f...
# 556  https://findwork-dev-images.s3.amazonaws.com/f...
# 559                                                NaN
# 578                                                NaN
# 614                                                NaN
# 692   https://findwork-dev-images.s3.amazonaws.com/AWS
#
#                                                    url  \
# 1    https://findwork.dev/M1pNwaQ/mid-engineering-r...
# 19   https://findwork.dev/M3GNp2M/seniorstaff-engin...
# 30   https://findwork.dev/M3GYPBM/biomedical-engine...
# 48   https://findwork.dev/MAdNAdQ/full-stack-fronte...
# 49   https://findwork.dev/MAdNwVQ/machine-learning-...
# 68   https://findwork.dev/MBjrE1M/risk-manager-liqu...
# 74   https://findwork.dev/MBjRzBM/platform-engineer...
# 86   https://findwork.dev/MdV9PDn/senior-industrial...
# 88   https://findwork.dev/MdV9xWn/multiple-roles-at...
# 91   https://findwork.dev/MdVg2xn/senior-developer-...
# 99   https://findwork.dev/MdVyVDn/ai-developer-at-a...
# 119  https://findwork.dev/MLrVron/research-software...
# 124  https://findwork.dev/MmjBeWX/software-engineer...
# 148  https://findwork.dev/MNNWzLM/senior-python-eng...
# 149  https://findwork.dev/MrJG9KM/quant-python-engi...
# 151  https://findwork.dev/MrJKArM/software-engineer...
# 185  https://findwork.dev/n2YKGbX/many-roles-sr-jav...
# 204  https://findwork.dev/n5ZN0eQ/software-engineer...
# 207  https://findwork.dev/n7le07Q/assistant-profess...
# 220  https://findwork.dev/n7lNYBQ/devopsdevex-engin...
# 230  https://findwork.dev/n98przX/senior-full-stack...
# 231  https://findwork.dev/n98qDJX/software-engineer...
# 242  https://findwork.dev/nal5qAX/software-engineer...
# 269  https://findwork.dev/nD5NAjQ/senior-software-e...
# 274  https://findwork.dev/njj0WZn/multiple-roles-at...
# 286  https://findwork.dev/njjzx2n/senior-front-end-...
# 328  https://findwork.dev/npR3EyM/data-software-eng...
# 345  https://findwork.dev/nvDY52M/vice-president-cr...
# 357  https://findwork.dev/nvDZwLM/multiple-roles-at...
# 435  https://findwork.dev/Q4qPwNM/front-end-enginee...
# 439  https://findwork.dev/Q4qRarM/director-trading-...
# 447  https://findwork.dev/Q6217gQ/senior-software-e...
# 449  https://findwork.dev/Q621oBQ/finance-cloud-ope...
# 450  https://findwork.dev/Q621omQ/senior-devops-eng...
# 475  https://findwork.dev/Qg6L4Rn/project-architect...
# 524  https://findwork.dev/QV5Bd7n/software-engineer...
# 545  https://findwork.dev/X88wapX/technical-product...
# 556  https://findwork.dev/XE59ErX/token-growth-asso...
# 559  https://findwork.dev/XE59mjX/industrial-produc...
# 578  https://findwork.dev/XkR9r5M/senior-frontend-e...
# 614  https://findwork.dev/XO9mlqQ/multiple-position...
# 692  https://findwork.dev/Xxq5yOn/senior-mid-level-...
#
#                                                   text           date_posted  \
# 1    We usually hire remote (USA) but we&#x27;ve pa...  2024-03-01T16:49:29Z
# 19   Hashboard is building a BI platform that makes...  2024-03-01T19:36:33Z
# 30   <em>About us:</em>\r\n\r\nQuantune Technologie...  2024-03-27T04:00:00Z
# 48   We are a small, highly ambitious and fun (argu...  2024-03-01T16:24:52Z
# 49   We are a Machine Learning consulting company t...  2024-03-02T17:28:52Z
# 68   <p>We are seeking an experienced individual wi...  2024-04-06T04:00:00Z
# 74   We are building an integrated MLOps platform b...  2024-05-01T21:01:26Z
# 86   <h3>Job description</h3>3M (New Health Care Co...  2024-04-15T20:08:00Z
# 88   At Seen, we believe that everyone deserves a f...  2024-04-02T11:23:18Z
# 91   Novata is pioneering the way in ESG (Environme...  2024-03-01T18:23:28Z
# 99   We&#x27;re looking for experienced people who ...  2024-05-01T17:26:47Z
# 119  At Emerging Technology Lab (ETL) that is a par...  2024-05-01T17:04:00Z
# 124  Our mission is to advance the landscape of int...  2024-04-02T10:39:03Z
# 148  At Datenna, we combine China expertise, OSINT,...  2024-03-06T08:31:47Z
# 149  Our systems are almost all running on Linux an...  2024-03-07T11:19:55Z
# 151  Fulcrum is building next generation storage pl...  2024-05-02T09:23:14Z
# 185  We are disrupting Google&#x27;s monopoly on se...  2024-05-01T17:22:19Z
# 204  We&#x27;re tackling fundamental issues that un...  2024-03-02T06:17:52Z
# 207  <h3>Job description</h3>The Design School at A...  2024-03-26T13:46:00Z
# 220  Opvia wants to be the software layer for regul...  2024-03-01T18:32:48Z
# 230  Bonside is an NYC-based fintech startup provid...  2024-05-03T21:04:27Z
# 231  We&#x27;re hiring an engineer to rework critic...  2024-04-02T01:32:45Z
# 242  Freeform is deploying software-defined, autono...  2024-03-13T16:53:37Z
# 269  As a company with roots in the open-source com...  2024-03-01T19:51:21Z
# 274  Learn about Asana&#x27;s engineering team via ...  2024-05-06T17:12:44Z
# 286  TandemAI is focused on lowering the barrier to...  2024-04-02T03:51:17Z
# 328  Ledger is looking to hire a Data & Software En...  2024-04-17T04:00:00Z
# 345  <h2>The Role</h2><p>Fidelity Digital Asset Man...  2024-03-26T04:00:00Z
# 357  Learn about Asana&#x27;s engineering team via ...  2024-03-14T20:03:30Z
# 435  At KPV LAB we are creating new visually stunni...  2024-03-01T18:41:57Z
# 439  <p>We are currently sourcing for a Director, T...  2024-04-24T04:00:00Z
# 447  On the RippleX team at Ripple, we champion the...  2024-05-03T18:23:14Z
# 449  Backblaze is a public company that makes it as...  2024-05-09T23:56:49Z
# 450  <h2>The Role</h2><p>You will be part of a trem...  2024-05-07T04:00:00Z
# 475  <h3>Job description</h3><p>Food Plant Engineer...  2024-03-05T02:29:00Z
# 524  - Full-Stack (e.g. build tools to visualize an...  2024-03-02T01:45:13Z
# 545  <h2>About Injective Labs</h2><p>Injective Labs...  2024-04-25T04:00:00Z
# 556  <h2>About Outlier Ventures</h2><p>Outlier Vent...  2024-04-12T04:00:00Z
# 559  <h3>Job description</h3>Join Puffy's team at o...  2024-03-26T05:02:00Z
# 578  At Neocom, we empower every company to underst...  2024-03-01T17:13:45Z
# 614  SIG is a global quantitative trading firm foun...  2024-04-01T21:24:45Z
# 692  Amazon Elastic MapReduce (EMR) is the industry...  2024-04-01T20:21:43Z
#
#                                               keywords              source  \
# 1                                           {k8s,rust}                  Hn
# 19                                             {react}                  Hn
# 30                                   {python,embedded}   Berlinstartupjobs
# 48             {react,ml,typescript,serverless,python}                  Hn
# 49        {ml,gcp,pytorch,tensorflow,aws,python,azure}                  Hn
# 68                                        {blockchain}  Cryptocurrencyjobs
# 74                                    {k8s,kubernetes}                  Hn
# 86                                          {embedded}            Coroflot
# 88                   {react,fintech,typescript,python}                  Hn
# 91                                    {k8s,typescript}                  Hn
# 99                                                  {}                  Hn
# 119                                         {etl,web3}                  Hn
# 124                               {typescript,aws,net}                  Hn
# 148   {pytest,django,fastapi,docker,python,kubernetes}                  Hn
# 149  {scipy,jenkins,ansible,pyramid,oracle,grafana,...                  Hn
# 151                               {github,python,rust}                  Hn
# 185                                  {react,python,ml}                  Hn
# 204                                       {typescript}                  Hn
# 207                                               {ux}            Coroflot
# 220                                    {terraform,gcp}                  Hn
# 230  {postgres,fintech,node,typescript,tailwind,pyt...                  Hn
# 231                                       {salesforce}                  Hn
# 242                                             {rust}                  Hn
# 269                                     {react,python}                  Hn
# 274                                                 {}                  Hn
# 286                                            {react}                  Hn
# 328                                           {ledger}  Cryptocurrencyjobs
# 345                                       {blockchain}  Cryptocurrencyjobs
# 357                                                 {}                  Hn
# 435           {react,graphql,typescript,postgres,node}                  Hn
# 439                             {ethereum,bitcoin,sql}  Cryptocurrencyjobs
# 447  {ledger,mysql,apache,postgresql,blockchain,cas...                  Hn
# 449                                              {php}                  Hn
# 450  {eks,blockchain,sql,python,prometheus,chef,ecs...  Cryptocurrencyjobs
# 475                                                 {}            Coroflot
# 524        {android,react,kotlin,qa,swift,ios,flutter}                  Hn
# 545                         {ethereum,blockchain,web3}  Cryptocurrencyjobs
# 556                                  {blockchain,web3}  Cryptocurrencyjobs
# 559                                         {coverage}            Coroflot
# 578                             {react,cypress,apollo}                  Hn
# 614                                           {python}                  Hn
# 692   {serverless,sql,spark,mapreduce,s3,hbase,apache}                  Hn
#
#                                 city                   country
# 1                            Unknown                   Unknown
# 19                          New York             United States
# 30                            Berlin                   Germany
# 48                         Stockholm                    Sweden
# 49                           Unknown                   Unknown
# 68                             Dubai      United Arab Emirates
# 74                           Unknown                   Unknown
# 86                         Maplewood             United States
# 88                            Berlin                   Germany
# 91                           Unknown                   Unknown
# 99                         Amsterdam               Netherlands
# 119                            Ouaka  Central African Republic
# 124                          Unknown                   Unknown
# 148                          Unknown                   Unknown
# 149                           London            United Kingdom
# 151                          Unknown                   Unknown
# 185                         New York             United States
# 204                          Unknown                   Unknown
# 207                            Tempe             United States
# 220                          Unknown                   Unknown
# 230  NYC Health + Hospitals/Bellevue             United States
# 231                    San Francisco             United States
# 242                      Los Angeles             United States
# 269                           Canada                    Canada
# 274                          Unknown                   Unknown
# 286                          Unknown                   Unknown
# 328                            Paris                    France
# 345                           Boston             United States
# 357                          Unknown                   Unknown
# 435                City of Edinburgh            United Kingdom
# 439                      Jersey City             United States
# 447                     Toronto Road            United Kingdom
# 449                 San Mateo County             United States
# 450                           Durham             United States
# 475                       Cincinnati             United States
# 524                          Unknown                   Unknown
# 545                         New York             United States
# 556                           London            United Kingdom
# 559                      Los Angeles             United States
# 578                           Munich                   Germany
# 614    Council of the City of Sydney                 Australia
# 692                          Redmond             United States

# %%
# Handle location column - create a table to map the original location to the city and country
# get only unique locations

map_location = fw_data.drop_duplicates(subset=['location'])
map_location[['city_geopy', 'country_geopy']] = map_location['location'].apply(lambda x: pd.Series(_parse_location(x)))

# Set values in all columns to lowercase
map_location = map_location.apply(lambda x: x.astype(str).str.lower())
# Out:
# C:\Users\jessicas\AppData\Local\Temp\ipykernel_21192\2342724613.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_location[['city_geopy', 'city_geopy']] = map_location['location'].apply(lambda x: pd.Series(_parse_location(x)))

# %%
map_location = map_location[['location', 'city_geopy', 'country_geopy']]

# %%
# convert location to lowercase
fw_data_raw['location'] = fw_data_raw['location'].str.lower()

test = pd.merge(fw_data_raw, map_location, on='location', how='left')

# %%
# remove all unknown locations
all_locations_clean = map_location[map_location['city'] != 'unknown']

# read_file = pd.read_csv("pop2.csv")
# # group by city and country and keep the record with the highest population in the test df
# idx = read_file.groupby(['city2', 'country2'])['rank'].idxmax()
# pop_summarise = read_file.loc[idx].reset_index(drop=True)
# # remove all unknown locations
# pop_summarise_clean = pop_summarise[pop_summarise['city2'] != 'unknown']

# %%
merged = pd.merge(all_locations_clean, pop_summarise_clean, how='left', left_on=['city', 'country'], right_on=['city2', 'country2'])

# select only the columns we need
merged = merged[['location','city_y', 'country_y','city2', 'country2']]

# %%
# group by city and country and count in the test df
pop_summarise = df_jobs_renamed.groupby(['city2', 'country2']).size().reset_index(name='count')

# group by city and country and keep the record with the highest rank in the fw_data df
# pop_summarise = test.groupby(['city', 'country']).apply(lambda x: x[x['rank'].idxmax()])

# group by city and country and keep the record with the highest population in the test df
# idx = test.groupby(['city2', 'country2'])['population'].idxmax()
# pop_summarise = test.loc[idx].reset_index(drop=True)
